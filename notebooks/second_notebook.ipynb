# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow

# %%
# import data
train = pd.read_csv('/Users/abdessamadbaahmed/Desktop/livrable_mp_data/data/nba_logreg_train.csv')

# %%
# define features and target
X_train = train.drop('TARGET_5Yrs', axis=1)
y_train = train['TARGET_5Yrs']

# %%
# setting the experiment 
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("nba-investment-experiment")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1673098660203, experiment_id='1', last_update_time=1673098660203, lifecycle_stage='active', name='nba-investment-experiment', tags={}>

# %%
# initialize mlflow client
client = mlflow.tracking.MlflowClient()

# Search for experiments
experiments = client.search_experiments()

# Print the experiment ID and name for each experiment
for experiment in experiments:
    print(f"Experiment ID: {experiment.experiment_id}")
    print(f"Experiment name: {experiment.name}")
# Out:
# Experiment ID: 1
# Experiment name: nba-investment-experiment
# Experiment ID: 0
# Experiment name: Default

# %%
# split the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# Convert the data to DMatrix objects
train_dmatrix = xgb.DMatrix(X_train, label=y_train)
validation_dmatrix = xgb.DMatrix(X_val, label=y_val)

# Define the objective function for the hyperparameter optimization
def objective(params):
    with mlflow.start_run():
        # Set the model and the search space in the run metadata
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)

        # Train the XGBoost model using the specified hyperparameters
        booster = xgb.train(
            params=params,
            dtrain=train_dmatrix,
            num_boost_round=1000,
            evals=[(validation_dmatrix, 'validation')],
            early_stopping_rounds=50
        )
        
        # Make predictions on the validation data
        y_pred = booster.predict(validation_dmatrix).round()
        
        # Calculate the evaluation scores
        accuracy = accuracy_score(y_val, y_pred)
        precision = precision_score(y_val, y_pred)
        recall = recall_score(y_val, y_pred)
        f1 = f1_score(y_val, y_pred)
        
        # Log the evaluation scores to MLFlow
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("recall", recall)
        mlflow.log_metric("f1_score", f1)

    return {'loss': 1 - f1, 'status': STATUS_OK}

# Define the search space for the hyperparameters
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'binary:logistic',
    'seed': 42
}

# Perform the hyperparameter optimization using the Tree Parzen Estimator algorithm
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-logloss:0.67926
# [1]	validation-logloss:0.66583
# [2]	validation-logloss:0.65627
# [3]	validation-logloss:0.64923
# [4]	validation-logloss:0.64094
# [5]	validation-logloss:0.63297
# [6]	validation-logloss:0.62784
# [7]	validation-logloss:0.62269
# [8]	validation-logloss:0.61857
# [9]	validation-logloss:0.61235
# [10]	validation-logloss:0.60580
# [11]	validation-logloss:0.60094
# [12]	validation-logloss:0.59769
# [13]	validation-logloss:0.59401
# [14]	validation-logloss:0.59075
# [15]	validation-logloss:0.58865
# [16]	validation-logloss:0.58633
# [17]	validation-logloss:0.58631
# [18]	validation-logloss:0.58476
# [19]	validation-logloss:0.58307
# [20]	validation-logloss:0.58099
# [21]	validation-logloss:0.58041
# [22]	validation-logloss:0.58007
# [23]	validation-logloss:0.58061
# [24]	validation-logloss:0.57984
# [25]	validation-logloss:0.57755
# [26]	validation-logloss:0.57550
# [27]	validation-logloss:0.57437
# [28]	validation-logloss:0.57407
# [29]	validation-logloss:0.57315
# [30]	validation-logloss:0.57380
# [31]	validation-logloss:0.57282
# [32]	validation-logloss:0.57314
# [33]	validation-logloss:0.57394
# [34]	validation-logloss:0.57295
# [35]	validation-logloss:0.57456
# [36]	validation-logloss:0.57562
# [37]	validation-logloss:0.57370
# [38]	validation-logloss:0.57508
# [39]	validation-logloss:0.57478
# [40]	validation-logloss:0.57502
# [41]	validation-logloss:0.57637
# [42]	validation-logloss:0.57797
# [43]	validation-logloss:0.57794
# [44]	validation-logloss:0.57881
# [45]	validation-logloss:0.57741
# [46]	validation-logloss:0.57615
# [47]	validation-logloss:0.57587
# [48]	validation-logloss:0.57688
# [49]	validation-logloss:0.57858
# [50]	validation-logloss:0.58038
# [51]	validation-logloss:0.58236
# [52]	validation-logloss:0.58209
# [53]	validation-logloss:0.58253
# [54]	validation-logloss:0.58216
# [55]	validation-logloss:0.58341
# [56]	validation-logloss:0.58219
# [57]	validation-logloss:0.58400
# [58]	validation-logloss:0.58530
# [59]	validation-logloss:0.58616
# [60]	validation-logloss:0.58813
# [61]	validation-logloss:0.58842
# [62]	validation-logloss:0.58817
# [63]	validation-logloss:0.58858
# [64]	validation-logloss:0.58850
# [65]	validation-logloss:0.58736
# [66]	validation-logloss:0.58859
# [67]	validation-logloss:0.58844
# [68]	validation-logloss:0.58865
# [69]	validation-logloss:0.59014
# [70]	validation-logloss:0.59081
# [71]	validation-logloss:0.59100
# [72]	validation-logloss:0.59150
# [73]	validation-logloss:0.59201
# [74]	validation-logloss:0.59130
# [75]	validation-logloss:0.59337
# [76]	validation-logloss:0.59344
# [77]	validation-logloss:0.59438
# [78]	validation-logloss:0.59560
# [79]	validation-logloss:0.59714
# [80]	validation-logloss:0.59804
# [0]	validation-logloss:0.67705
# [1]	validation-logloss:0.65278
# [2]	validation-logloss:0.63785
# [3]	validation-logloss:0.63304
# [4]	validation-logloss:0.64902
# [5]	validation-logloss:0.65417
# [6]	validation-logloss:0.66110
# [7]	validation-logloss:0.65836
# [8]	validation-logloss:0.66000
# [9]	validation-logloss:0.66085
# [10]	validation-logloss:0.66514
# [11]	validation-logloss:0.66422
# [12]	validation-logloss:0.66847
# [13]	validation-logloss:0.67209
# [14]	validation-logloss:0.68148
# [15]	validation-logloss:0.68447
# [16]	validation-logloss:0.68884
# [17]	validation-logloss:0.69470
# [18]	validation-logloss:0.70236
# [19]	validation-logloss:0.70746
# [20]	validation-logloss:0.71328
# [21]	validation-logloss:0.71851
# [22]	validation-logloss:0.73404
# [23]	validation-logloss:0.73792
# [24]	validation-logloss:0.74340
# [25]	validation-logloss:0.74853
# [26]	validation-logloss:0.74844
# [27]	validation-logloss:0.75331
# [28]	validation-logloss:0.75165
# [29]	validation-logloss:0.76176
# [30]	validation-logloss:0.77100
# [31]	validation-logloss:0.77588
# [32]	validation-logloss:0.77575
# [33]	validation-logloss:0.77109
# [34]	validation-logloss:0.77169
# [35]	validation-logloss:0.77955
# [36]	validation-logloss:0.78230
# [37]	validation-logloss:0.78108
# [38]	validation-logloss:0.78708
# [39]	validation-logloss:0.79027
# [40]	validation-logloss:0.79229
# [41]	validation-logloss:0.79394
# [42]	validation-logloss:0.79664
# [43]	validation-logloss:0.80128
# [44]	validation-logloss:0.80987
# [45]	validation-logloss:0.81184
# [46]	validation-logloss:0.81342
# [47]	validation-logloss:0.81933
# [48]	validation-logloss:0.82380
# [49]	validation-logloss:0.82946
# [50]	validation-logloss:0.83334
# [51]	validation-logloss:0.83452
# [52]	validation-logloss:0.83575
# [53]	validation-logloss:0.83807
# [0]	validation-logloss:0.67053
# [1]	validation-logloss:0.64953
# [2]	validation-logloss:0.63636
# [3]	validation-logloss:0.62323
# [4]	validation-logloss:0.61500
# [5]	validation-logloss:0.60832
# [6]	validation-logloss:0.60119
# [7]	validation-logloss:0.59472
# [8]	validation-logloss:0.58958
# [9]	validation-logloss:0.58514
# [10]	validation-logloss:0.58260
# [11]	validation-logloss:0.57808
# [12]	validation-logloss:0.57729
# [13]	validation-logloss:0.57583
# [14]	validation-logloss:0.57295
# [15]	validation-logloss:0.57275
# [16]	validation-logloss:0.57207
# [17]	validation-logloss:0.57161
# [18]	validation-logloss:0.57207
# [19]	validation-logloss:0.57408
# [20]	validation-logloss:0.57345
# [21]	validation-logloss:0.57557
# [22]	validation-logloss:0.57370
# [23]	validation-logloss:0.57198
# [24]	validation-logloss:0.57078
# [25]	validation-logloss:0.57072
# [26]	validation-logloss:0.57198
# [27]	validation-logloss:0.57094
# [28]	validation-logloss:0.57339
# [29]	validation-logloss:0.57504
# [30]	validation-logloss:0.57678
# [31]	validation-logloss:0.57833
# [32]	validation-logloss:0.58045
# [33]	validation-logloss:0.58123
# [34]	validation-logloss:0.58305
# [35]	validation-logloss:0.58583
# [36]	validation-logloss:0.58664
# [37]	validation-logloss:0.58663
# [38]	validation-logloss:0.58785
# [39]	validation-logloss:0.58793
# [40]	validation-logloss:0.58956
# [41]	validation-logloss:0.58929
# [42]	validation-logloss:0.58936
# [43]	validation-logloss:0.59052
# [44]	validation-logloss:0.59252
# [45]	validation-logloss:0.59336
# [46]	validation-logloss:0.59398
# [47]	validation-logloss:0.59362
# [48]	validation-logloss:0.59397
# [49]	validation-logloss:0.59325
# [50]	validation-logloss:0.59373
# [51]	validation-logloss:0.59441
# [52]	validation-logloss:0.59600
# [53]	validation-logloss:0.59628
# [54]	validation-logloss:0.59726
# [55]	validation-logloss:0.59859
# [56]	validation-logloss:0.60023
# [57]	validation-logloss:0.59955
# [58]	validation-logloss:0.60050
# [59]	validation-logloss:0.60085
# [60]	validation-logloss:0.60280
# [61]	validation-logloss:0.60556
# [62]	validation-logloss:0.60586
# [63]	validation-logloss:0.60695
# [64]	validation-logloss:0.60481
# [65]	validation-logloss:0.60446
# [66]	validation-logloss:0.60722
# [67]	validation-logloss:0.60588
# [68]	validation-logloss:0.60772
# [69]	validation-logloss:0.60598
# [70]	validation-logloss:0.60380
# [71]	validation-logloss:0.60594
# [72]	validation-logloss:0.60603
# [73]	validation-logloss:0.60890
# [74]	validation-logloss:0.61113
# [0]	validation-logloss:0.67870
# [1]	validation-logloss:0.66442
# [2]	validation-logloss:0.65394
# [3]	validation-logloss:0.64629
# [4]	validation-logloss:0.63676
# [5]	validation-logloss:0.62876
# [6]	validation-logloss:0.62059
# [7]	validation-logloss:0.61454
# [8]	validation-logloss:0.60910
# [9]	validation-logloss:0.60565
# [10]	validation-logloss:0.60028
# [11]	validation-logloss:0.59573
# [12]	validation-logloss:0.59069
# [13]	validation-logloss:0.58797
# [14]	validation-logloss:0.58512
# [15]	validation-logloss:0.58201
# [16]	validation-logloss:0.57810
# [17]	validation-logloss:0.57661
# [18]	validation-logloss:0.57642
# [19]	validation-logloss:0.57419
# [20]	validation-logloss:0.57210
# [21]	validation-logloss:0.56803
# [22]	validation-logloss:0.56709
# [23]	validation-logloss:0.56554
# [24]	validation-logloss:0.56254
# [25]	validation-logloss:0.55971
# [26]	validation-logloss:0.55831
# [27]	validation-logloss:0.55772
# [28]	validation-logloss:0.55689
# [29]	validation-logloss:0.55608
# [30]	validation-logloss:0.55650
# [31]	validation-logloss:0.55722
# [32]	validation-logloss:0.55788
# [33]	validation-logloss:0.55702
# [34]	validation-logloss:0.55700
# [35]	validation-logloss:0.55728
# [36]	validation-logloss:0.55755
# [37]	validation-logloss:0.55779
# [38]	validation-logloss:0.55872
# [39]	validation-logloss:0.55944
# [40]	validation-logloss:0.55875
# [41]	validation-logloss:0.55649
# [42]	validation-logloss:0.55643
# [43]	validation-logloss:0.55665
# [44]	validation-logloss:0.55686
# [45]	validation-logloss:0.55673
# [46]	validation-logloss:0.55650
# [47]	validation-logloss:0.55671
# [48]	validation-logloss:0.55726
# [49]	validation-logloss:0.55640
# [50]	validation-logloss:0.55785
# [51]	validation-logloss:0.55981
# [52]	validation-logloss:0.56054
# [53]	validation-logloss:0.56073
# [54]	validation-logloss:0.56037
# [55]	validation-logloss:0.56050
# [56]	validation-logloss:0.56077
# [57]	validation-logloss:0.56143
# [58]	validation-logloss:0.56222
# [59]	validation-logloss:0.56289
# [60]	validation-logloss:0.56269
# [61]	validation-logloss:0.56431
# [62]	validation-logloss:0.56400
# [63]	validation-logloss:0.56479
# [64]	validation-logloss:0.56357
# [65]	validation-logloss:0.56657
# [66]	validation-logloss:0.56683
# [67]	validation-logloss:0.56778
# [68]	validation-logloss:0.56877
# [69]	validation-logloss:0.56853
# [70]	validation-logloss:0.56822
# [71]	validation-logloss:0.56837
# [72]	validation-logloss:0.56827
# [73]	validation-logloss:0.56972
# [74]	validation-logloss:0.57100
# [75]	validation-logloss:0.57143
# [76]	validation-logloss:0.57179
# [77]	validation-logloss:0.57314
# [78]	validation-logloss:0.57224
# [0]	validation-logloss:0.71263
# [1]	validation-logloss:0.72718
# [2]	validation-logloss:0.75094
# [3]	validation-logloss:0.79437
# [4]	validation-logloss:0.81122
# [5]	validation-logloss:0.80923
# [6]	validation-logloss:0.84505
# [7]	validation-logloss:0.86124
# [8]	validation-logloss:0.87125
# [9]	validation-logloss:0.88624
# [10]	validation-logloss:0.90242
# [11]	validation-logloss:0.92359
# [12]	validation-logloss:0.92776
# [13]	validation-logloss:0.95343
# [14]	validation-logloss:0.96369
# [15]	validation-logloss:0.97970
# [16]	validation-logloss:0.98112
# [17]	validation-logloss:0.98637
# [18]	validation-logloss:0.99132
# [19]	validation-logloss:0.99124
# [20]	validation-logloss:0.98871
# [21]	validation-logloss:0.99115
# [22]	validation-logloss:0.99519
# [23]	validation-logloss:0.99676
# [24]	validation-logloss:1.00092
# [25]	validation-logloss:1.00283
# [26]	validation-logloss:1.00651
# [27]	validation-logloss:1.00384
# [28]	validation-logloss:1.00673
# [29]	validation-logloss:1.00939
# [30]	validation-logloss:1.00940
# [31]	validation-logloss:1.01057
# [32]	validation-logloss:1.01343
# [33]	validation-logloss:1.01946
# [34]	validation-logloss:1.02034
# [35]	validation-logloss:1.02612
# [36]	validation-logloss:1.02365
# [37]	validation-logloss:1.02584
# [38]	validation-logloss:1.02677
# [39]	validation-logloss:1.02890
# [40]	validation-logloss:1.02890
# [41]	validation-logloss:1.02890
# [42]	validation-logloss:1.02890
# [43]	validation-logloss:1.02890
# [44]	validation-logloss:1.02890
# [45]	validation-logloss:1.02890
# [46]	validation-logloss:1.02890
# [47]	validation-logloss:1.02890
# [48]	validation-logloss:1.02890
# [49]	validation-logloss:1.02890
# [50]	validation-logloss:1.02890
# [0]	validation-logloss:0.67936
# [1]	validation-logloss:0.66755
# [2]	validation-logloss:0.65662
# [3]	validation-logloss:0.64671
# [4]	validation-logloss:0.63931
# [5]	validation-logloss:0.63128
# [6]	validation-logloss:0.62392
# [7]	validation-logloss:0.61721
# [8]	validation-logloss:0.61143
# [9]	validation-logloss:0.60710
# [10]	validation-logloss:0.60173
# [11]	validation-logloss:0.59704
# [12]	validation-logloss:0.59324
# [13]	validation-logloss:0.58960
# [14]	validation-logloss:0.58654
# [15]	validation-logloss:0.58290
# [16]	validation-logloss:0.58004
# [17]	validation-logloss:0.57838
# [18]	validation-logloss:0.57599
# [19]	validation-logloss:0.57304
# [20]	validation-logloss:0.57005
# [21]	validation-logloss:0.56806
# [22]	validation-logloss:0.56649
# [23]	validation-logloss:0.56568
# [24]	validation-logloss:0.56463
# [25]	validation-logloss:0.56335
# [26]	validation-logloss:0.56182
# [27]	validation-logloss:0.56032
# [28]	validation-logloss:0.55951
# [29]	validation-logloss:0.55899
# [30]	validation-logloss:0.55839
# [31]	validation-logloss:0.55770
# [32]	validation-logloss:0.55654
# [33]	validation-logloss:0.55621
# [34]	validation-logloss:0.55545
# [35]	validation-logloss:0.55461
# [36]	validation-logloss:0.55464
# [37]	validation-logloss:0.55420
# [38]	validation-logloss:0.55353
# [39]	validation-logloss:0.55371
# [40]	validation-logloss:0.55243
# [41]	validation-logloss:0.55240
# [42]	validation-logloss:0.55206
# [43]	validation-logloss:0.55274
# [44]	validation-logloss:0.55266
# [45]	validation-logloss:0.55221
# [46]	validation-logloss:0.55273
# [47]	validation-logloss:0.55292
# [48]	validation-logloss:0.55271
# [49]	validation-logloss:0.55327
# [50]	validation-logloss:0.55314
# [51]	validation-logloss:0.55373
# [52]	validation-logloss:0.55308
# [53]	validation-logloss:0.55269
# [54]	validation-logloss:0.55256
# [55]	validation-logloss:0.55291
# [56]	validation-logloss:0.55316
# [57]	validation-logloss:0.55317
# [58]	validation-logloss:0.55316
# [59]	validation-logloss:0.55279
# [60]	validation-logloss:0.55293
# [61]	validation-logloss:0.55302
# [62]	validation-logloss:0.55361
# [63]	validation-logloss:0.55315
# [64]	validation-logloss:0.55302
# [65]	validation-logloss:0.55277
# [66]	validation-logloss:0.55326
# [67]	validation-logloss:0.55355
# [68]	validation-logloss:0.55394
# [69]	validation-logloss:0.55360
# [70]	validation-logloss:0.55458
# [71]	validation-logloss:0.55482
# [72]	validation-logloss:0.55447
# [73]	validation-logloss:0.55371
# [74]	validation-logloss:0.55428
# [75]	validation-logloss:0.55478
# [76]	validation-logloss:0.55485
# [77]	validation-logloss:0.55568
# [78]	validation-logloss:0.55544
# [79]	validation-logloss:0.55545
# [80]	validation-logloss:0.55511
# [81]	validation-logloss:0.55531
# [82]	validation-logloss:0.55523
# [83]	validation-logloss:0.55611
# [84]	validation-logloss:0.55550
# [85]	validation-logloss:0.55558
# [86]	validation-logloss:0.55540
# [87]	validation-logloss:0.55631
# [88]	validation-logloss:0.55505
# [89]	validation-logloss:0.55555
# [90]	validation-logloss:0.55599
# [91]	validation-logloss:0.55589
# [0]	validation-logloss:0.60527
# [1]	validation-logloss:0.58584
# [2]	validation-logloss:0.58880
# [3]	validation-logloss:0.60161
# [4]	validation-logloss:0.61645
# [5]	validation-logloss:0.63332
# [6]	validation-logloss:0.64671
# [7]	validation-logloss:0.64955
# [8]	validation-logloss:0.65251
# [9]	validation-logloss:0.65979
# [10]	validation-logloss:0.66149
# [11]	validation-logloss:0.65748
# [12]	validation-logloss:0.66799
# [13]	validation-logloss:0.67656
# [14]	validation-logloss:0.68220
# [15]	validation-logloss:0.67588
# [16]	validation-logloss:0.68117
# [17]	validation-logloss:0.68111
# [18]	validation-logloss:0.67128
# [19]	validation-logloss:0.67818
# [20]	validation-logloss:0.68787
# [21]	validation-logloss:0.70353
# [22]	validation-logloss:0.70872
# [23]	validation-logloss:0.70738
# [24]	validation-logloss:0.70203
# [25]	validation-logloss:0.70659
# [26]	validation-logloss:0.70340
# [27]	validation-logloss:0.71009
# [28]	validation-logloss:0.72011
# [29]	validation-logloss:0.73258
# [30]	validation-logloss:0.73493
# [31]	validation-logloss:0.74208
# [32]	validation-logloss:0.74345
# [33]	validation-logloss:0.74809
# [34]	validation-logloss:0.75142
# [35]	validation-logloss:0.75946
# [36]	validation-logloss:0.75852
# [37]	validation-logloss:0.75740
# [38]	validation-logloss:0.75862
# [39]	validation-logloss:0.75755
# [40]	validation-logloss:0.76199
# [41]	validation-logloss:0.76647
# [42]	validation-logloss:0.76973
# [43]	validation-logloss:0.77554
# [44]	validation-logloss:0.77889
# [45]	validation-logloss:0.78758
# [46]	validation-logloss:0.79272
# [47]	validation-logloss:0.79529
# [48]	validation-logloss:0.79647
# [49]	validation-logloss:0.80030
# [50]	validation-logloss:0.79913
# [0]	validation-logloss:0.67052
# [1]	validation-logloss:0.65083
# [2]	validation-logloss:0.63854
# [3]	validation-logloss:0.62381
# [4]	validation-logloss:0.60965
# [5]	validation-logloss:0.59864
# [6]	validation-logloss:0.58990
# [7]	validation-logloss:0.58221
# [8]	validation-logloss:0.57920
# [9]	validation-logloss:0.57318
# [10]	validation-logloss:0.57000
# [11]	validation-logloss:0.57217
# [12]	validation-logloss:0.56834
# [13]	validation-logloss:0.56973
# [14]	validation-logloss:0.56873
# [15]	validation-logloss:0.56887
# [16]	validation-logloss:0.56978
# [17]	validation-logloss:0.57196
# [18]	validation-logloss:0.57550
# [19]	validation-logloss:0.57516
# [20]	validation-logloss:0.57513
# [21]	validation-logloss:0.57362
# [22]	validation-logloss:0.57288
# [23]	validation-logloss:0.57385
# [24]	validation-logloss:0.57275
# [25]	validation-logloss:0.56933
# [26]	validation-logloss:0.57035
# [27]	validation-logloss:0.57120
# [28]	validation-logloss:0.57346
# [29]	validation-logloss:0.57358
# [30]	validation-logloss:0.57377
# [31]	validation-logloss:0.57598
# [32]	validation-logloss:0.57793
# [33]	validation-logloss:0.57851
# [34]	validation-logloss:0.58179
# [35]	validation-logloss:0.58399
# [36]	validation-logloss:0.58620
# [37]	validation-logloss:0.58629
# [38]	validation-logloss:0.58997
# [39]	validation-logloss:0.58983
# [40]	validation-logloss:0.59409
# [41]	validation-logloss:0.59616
# [42]	validation-logloss:0.60079
# [43]	validation-logloss:0.60408
# [44]	validation-logloss:0.60739
# [45]	validation-logloss:0.60766
# [46]	validation-logloss:0.60932
# [47]	validation-logloss:0.60936
# [48]	validation-logloss:0.61148
# [49]	validation-logloss:0.61510
# [50]	validation-logloss:0.61815
# [51]	validation-logloss:0.61778
# [52]	validation-logloss:0.62017
# [53]	validation-logloss:0.62155
# [54]	validation-logloss:0.62228
# [55]	validation-logloss:0.62389
# [56]	validation-logloss:0.62463
# [57]	validation-logloss:0.62791
# [58]	validation-logloss:0.62713
# [59]	validation-logloss:0.63122
# [60]	validation-logloss:0.63176
# [61]	validation-logloss:0.63387
# [0]	validation-logloss:0.64930
# [1]	validation-logloss:0.61944
# [2]	validation-logloss:0.59949
# [3]	validation-logloss:0.59163
# [4]	validation-logloss:0.58147
# [5]	validation-logloss:0.57660
# [6]	validation-logloss:0.56990
# [7]	validation-logloss:0.57031
# [8]	validation-logloss:0.56994
# [9]	validation-logloss:0.56982
# [10]	validation-logloss:0.57154
# [11]	validation-logloss:0.57209
# [12]	validation-logloss:0.57444
# [13]	validation-logloss:0.57764
# [14]	validation-logloss:0.56930
# [15]	validation-logloss:0.57278
# [16]	validation-logloss:0.57311
# [17]	validation-logloss:0.57721
# [18]	validation-logloss:0.57591
# [19]	validation-logloss:0.57871
# [20]	validation-logloss:0.57572
# [21]	validation-logloss:0.57526
# [22]	validation-logloss:0.57424
# [23]	validation-logloss:0.57802
# [24]	validation-logloss:0.57959
# [25]	validation-logloss:0.58383
# [26]	validation-logloss:0.58234
# [27]	validation-logloss:0.58853
# [28]	validation-logloss:0.58636
# [29]	validation-logloss:0.58950
# [30]	validation-logloss:0.59080
# [31]	validation-logloss:0.59139
# [32]	validation-logloss:0.59237
# [33]	validation-logloss:0.59980
# [34]	validation-logloss:0.60220
# [35]	validation-logloss:0.60478
# [36]	validation-logloss:0.60739
# [37]	validation-logloss:0.61059
# [38]	validation-logloss:0.61273
# [39]	validation-logloss:0.61304
# [40]	validation-logloss:0.61002
# [41]	validation-logloss:0.61341
# [42]	validation-logloss:0.61612
# [43]	validation-logloss:0.61720
# [44]	validation-logloss:0.61738
# [45]	validation-logloss:0.61986
# [46]	validation-logloss:0.61947
# [47]	validation-logloss:0.62003
# [48]	validation-logloss:0.62008
# [49]	validation-logloss:0.62267
# [50]	validation-logloss:0.62510
# [51]	validation-logloss:0.62646
# [52]	validation-logloss:0.62713
# [53]	validation-logloss:0.62789
# [54]	validation-logloss:0.62936
# [55]	validation-logloss:0.62938
# [56]	validation-logloss:0.63167
# [57]	validation-logloss:0.63562
# [58]	validation-logloss:0.63663
# [59]	validation-logloss:0.63930
# [60]	validation-logloss:0.64158
# [61]	validation-logloss:0.64151
# [62]	validation-logloss:0.64245
# [63]	validation-logloss:0.64421
# [64]	validation-logloss:0.64682
# [0]	validation-logloss:0.64744
# [1]	validation-logloss:0.61452
# [2]	validation-logloss:0.59797
# [3]	validation-logloss:0.58261
# [4]	validation-logloss:0.56811
# [5]	validation-logloss:0.56160
# [6]	validation-logloss:0.55628
# [7]	validation-logloss:0.55508
# [8]	validation-logloss:0.55509
# [9]	validation-logloss:0.54972
# [10]	validation-logloss:0.55129
# [11]	validation-logloss:0.54983
# [12]	validation-logloss:0.55387
# [13]	validation-logloss:0.55037
# [14]	validation-logloss:0.55325
# [15]	validation-logloss:0.55785
# [16]	validation-logloss:0.55883
# [17]	validation-logloss:0.56407
# [18]	validation-logloss:0.56927
# [19]	validation-logloss:0.56660
# [20]	validation-logloss:0.56577
# [21]	validation-logloss:0.56930
# [22]	validation-logloss:0.56964
# [23]	validation-logloss:0.57080
# [24]	validation-logloss:0.57178
# [25]	validation-logloss:0.57735
# [26]	validation-logloss:0.57881
# [27]	validation-logloss:0.58128
# ...
# [17]	validation-logloss:0.55814
# [18]	validation-logloss:0.55748
# [19]	validation-logloss:0.56301
# [20]	validation-logloss:0.56484
# [21]	validation-logloss:0.57027
# [22]	validation-logloss:0.57379
# [23]	validation-logloss:0.57442
# [24]	validation-logloss:0.57614
# [25]	validation-logloss:0.58255
# [26]	validation-logloss:0.58327
# [27]	validation-logloss:0.58522
# [28]	validation-logloss:0.58730
# [29]	validation-logloss:0.59185
# [30]	validation-logloss:0.59204
# [31]	validation-logloss:0.59360
# [32]	validation-logloss:0.59458
# [33]	validation-logloss:0.59514
# [34]	validation-logloss:0.59587
# [35]	validation-logloss:0.59906
# [36]	validation-logloss:0.60106
# [37]	validation-logloss:0.60506
# [38]	validation-logloss:0.60775
# [39]	validation-logloss:0.61160
# [40]	validation-logloss:0.61586
# [41]	validation-logloss:0.61973
# [42]	validation-logloss:0.62333
# [43]	validation-logloss:0.62226
# [44]	validation-logloss:0.62549
# [45]	validation-logloss:0.62634
# [46]	validation-logloss:0.62600
# [47]	validation-logloss:0.62967
# [48]	validation-logloss:0.62942
# [49]	validation-logloss:0.63503
# [50]	validation-logloss:0.63854
# [51]	validation-logloss:0.63974
# [52]	validation-logloss:0.64488
# [53]	validation-logloss:0.64717
# [54]	validation-logloss:0.64614
# [55]	validation-logloss:0.65165
# [56]	validation-logloss:0.65314
# [57]	validation-logloss:0.65619
# [58]	validation-logloss:0.65614
# [59]	validation-logloss:0.65945
# [60]	validation-logloss:0.66187
# [0]	validation-logloss:0.67983
# [1]	validation-logloss:0.66477
# [2]	validation-logloss:0.66030
# [3]	validation-logloss:0.65357
# [4]	validation-logloss:0.64683
# [5]	validation-logloss:0.63795
# [6]	validation-logloss:0.63261
# [7]	validation-logloss:0.62957
# [8]	validation-logloss:0.62769
# [9]	validation-logloss:0.62272
# [10]	validation-logloss:0.62104
# [11]	validation-logloss:0.61844
# [12]	validation-logloss:0.61456
# [13]	validation-logloss:0.61190
# [14]	validation-logloss:0.61028
# [15]	validation-logloss:0.60894
# [16]	validation-logloss:0.61086
# [17]	validation-logloss:0.60880
# [18]	validation-logloss:0.60773
# [19]	validation-logloss:0.60429
# [20]	validation-logloss:0.60551
# [21]	validation-logloss:0.60499
# [22]	validation-logloss:0.60514
# [23]	validation-logloss:0.60502
# [24]	validation-logloss:0.60288
# [25]	validation-logloss:0.60184
# [26]	validation-logloss:0.60200
# [27]	validation-logloss:0.60256
# [28]	validation-logloss:0.60273
# [29]	validation-logloss:0.60508
# [30]	validation-logloss:0.60601
# [31]	validation-logloss:0.60434
# [32]	validation-logloss:0.60440
# [33]	validation-logloss:0.60489
# [34]	validation-logloss:0.60865
# [35]	validation-logloss:0.61052
# [36]	validation-logloss:0.61182
# [37]	validation-logloss:0.61184
# [38]	validation-logloss:0.61162
# [39]	validation-logloss:0.61425
# [40]	validation-logloss:0.61630
# [41]	validation-logloss:0.61711
# [42]	validation-logloss:0.61695
# [43]	validation-logloss:0.61700
# [44]	validation-logloss:0.61682
# [45]	validation-logloss:0.61841
# [46]	validation-logloss:0.61948
# [47]	validation-logloss:0.62239
# [48]	validation-logloss:0.62347
# [49]	validation-logloss:0.62361
# [50]	validation-logloss:0.62485
# [51]	validation-logloss:0.62702
# [52]	validation-logloss:0.62944
# [53]	validation-logloss:0.63034
# [54]	validation-logloss:0.63109
# [55]	validation-logloss:0.63168
# [56]	validation-logloss:0.63074
# [57]	validation-logloss:0.63237
# [58]	validation-logloss:0.63316
# [59]	validation-logloss:0.63330
# [60]	validation-logloss:0.63571
# [61]	validation-logloss:0.63588
# [62]	validation-logloss:0.63984
# [63]	validation-logloss:0.64237
# [64]	validation-logloss:0.64483
# [65]	validation-logloss:0.64623
# [66]	validation-logloss:0.64712
# [67]	validation-logloss:0.64702
# [68]	validation-logloss:0.64797
# [69]	validation-logloss:0.65086
# [70]	validation-logloss:0.65165
# [71]	validation-logloss:0.65277
# [72]	validation-logloss:0.65444
# [73]	validation-logloss:0.65656
# [74]	validation-logloss:0.65629
# [75]	validation-logloss:0.65762
# [0]	validation-logloss:0.67025
# [1]	validation-logloss:0.65100
# [2]	validation-logloss:0.63801
# [3]	validation-logloss:0.62333
# [4]	validation-logloss:0.61293
# [5]	validation-logloss:0.60325
# [6]	validation-logloss:0.59398
# [7]	validation-logloss:0.58766
# [8]	validation-logloss:0.58410
# [9]	validation-logloss:0.57846
# [10]	validation-logloss:0.57378
# [11]	validation-logloss:0.57134
# [12]	validation-logloss:0.56800
# [13]	validation-logloss:0.56462
# [14]	validation-logloss:0.56295
# [15]	validation-logloss:0.55972
# [16]	validation-logloss:0.55773
# [17]	validation-logloss:0.55542
# [18]	validation-logloss:0.55352
# [19]	validation-logloss:0.55074
# [20]	validation-logloss:0.55074
# [21]	validation-logloss:0.54978
# [22]	validation-logloss:0.55005
# [23]	validation-logloss:0.54881
# [24]	validation-logloss:0.54904
# [25]	validation-logloss:0.54772
# [26]	validation-logloss:0.54830
# [27]	validation-logloss:0.54832
# [28]	validation-logloss:0.54892
# [29]	validation-logloss:0.55047
# [30]	validation-logloss:0.55039
# [31]	validation-logloss:0.55105
# [32]	validation-logloss:0.55138
# [33]	validation-logloss:0.55233
# [34]	validation-logloss:0.55334
# [35]	validation-logloss:0.55385
# [36]	validation-logloss:0.55401
# [37]	validation-logloss:0.55438
# [38]	validation-logloss:0.55650
# [39]	validation-logloss:0.55772
# [40]	validation-logloss:0.55809
# [41]	validation-logloss:0.55777
# [42]	validation-logloss:0.55874
# [43]	validation-logloss:0.55991
# [44]	validation-logloss:0.56087
# [45]	validation-logloss:0.56072
# [46]	validation-logloss:0.56082
# [47]	validation-logloss:0.56168
# [48]	validation-logloss:0.56301
# [49]	validation-logloss:0.56410
# [50]	validation-logloss:0.56453
# [51]	validation-logloss:0.56589
# [52]	validation-logloss:0.56792
# [53]	validation-logloss:0.56725
# [54]	validation-logloss:0.56728
# [55]	validation-logloss:0.56932
# [56]	validation-logloss:0.57099
# [57]	validation-logloss:0.56964
# [58]	validation-logloss:0.57026
# [59]	validation-logloss:0.57165
# [60]	validation-logloss:0.57212
# [61]	validation-logloss:0.57255
# [62]	validation-logloss:0.57318
# [63]	validation-logloss:0.57148
# [64]	validation-logloss:0.57268
# [65]	validation-logloss:0.57345
# [66]	validation-logloss:0.57384
# [67]	validation-logloss:0.57419
# [68]	validation-logloss:0.57533
# [69]	validation-logloss:0.57635
# [70]	validation-logloss:0.57753
# [71]	validation-logloss:0.57771
# [72]	validation-logloss:0.57762
# [73]	validation-logloss:0.57879
# [74]	validation-logloss:0.57794
# [75]	validation-logloss:0.57621
# 100%|██████████| 50/50 [00:30<00:00,  1.64trial/s, best loss: 0.209964412811388]

# %%
best_result
# Out:
# {'learning_rate': 0.12733162898151917,
#  'max_depth': 47.0,
#  'min_child_weight': 14.94503580200527,
#  'reg_alpha': 0.07462833916308295,
#  'reg_lambda': 0.014349514140204129}

# %%
# import k-fold cross validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)


for train_index, val_index in kf.split(X_train):
    # Split the data into training and validation sets
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

# %%
X_train[100]

# %%
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import numpy as np


# Define the objective function for the hyperparameter optimization
def objective(params, X_train, y_train, k=5):

    X_train = X_train.values
    y_train = y_train.values

    # Convert the data to DMatrix objects
    train_dmatrix = xgb.DMatrix(X_train, label=y_train)

    with mlflow.start_run():
        # Set the model and the search space in the run metadata
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)

        # Create a KFold object for cross-validation
        kf = KFold(n_splits=k, shuffle=True, random_state=42)

        # Initialize the evaluation scores
        accuracy = []
        precision = []
        recall = []
        f1 = []

        # Iterate over the folds
        for train_index, val_index in kf.split(X_train):
            # Split the data into training and validation sets
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            # Convert the data to DMatrix objects
            train_fold_dmatrix = xgb.DMatrix(X_train_fold, label=y_train_fold)
            val_fold_dmatrix = xgb.DMatrix(X_val_fold, label=y_val_fold)

            # Train the XGBoost model using the specified hyperparameters
            booster = xgb.train(
                params=params,
                dtrain=train_fold_dmatrix,
                num_boost_round=1000,
                evals=[(val_fold_dmatrix, 'validation')],
                early_stopping_rounds=50
            )
            
            # Make predictions on the validation data
            y_pred = booster.predict(val_fold_dmatrix).round()

            # Calculate the evaluation scores for the fold
            accuracy.append(accuracy_score(y_val_fold, y_pred))
            precision.append(precision_score(y_val_fold, y_pred))
            recall.append(recall_score(y_val_fold, y_pred))
            f1.append(f1_score(y_val_fold, y_pred))

        # Calculate the mean evaluation scores over all the folds
        mean_accuracy = np.mean(accuracy)
        mean_precision = np.mean(precision)
        mean_recall = np.mean(recall)
        mean_f1 = np.mean(f1)
        
        # Log the evaluation scores to MLFlow
        mlflow.log_metric("accuracy", mean_accuracy)
        mlflow.log_metric("precision", mean_precision)
        mlflow.log_metric("recall", mean_recall)
        mlflow.log_metric("f1_score", mean_f1)

    return {'loss': 1 - mean_f1, 'status': STATUS_OK}

# %%
# Define the search space for the hyperparameters
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'binary:logistic',
    'seed': 42
}

# %%
# Perform the hyperparameter optimization using the Tree Parzen Estimator algorithm
def wrapper(params):
    return objective(k=5, X_train=X_train, y_train=y_train, params=params)

best_result = fmin(
    fn=wrapper,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
